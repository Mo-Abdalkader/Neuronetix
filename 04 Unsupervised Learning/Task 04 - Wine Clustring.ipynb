# %%
# Out:
#  ______  ___     ______                        _________
# ___   |/  /________  /_______ _______ ______________  /
# __  /|_/ /_  __ \_  __ \  __ `/_  __ `__ \  _ \  __  /
# _  /  / / / /_/ /  / / / /_/ /_  / / / / /  __/ /_/ /
# /_/  /_/  \____//_/ /_/\__,_/ /_/ /_/ /_/\___/\__,_/
#
# _____________ _________      ___________        _________
# ___    |__  /_______  /_____ ___  /__  /_______ ______  /____________
# __  /| |_  __ \  __  /_  __ `/_  /__  //_/  __ `/  __  /_  _ \_  ___/
# _  ___ |  /_/ / /_/ / / /_/ /_  / _  ,<  / /_/ // /_/ / /  __/  /
# /_/  |_/_.___/\__,_/  \__,_/ /_/  /_/|_| \__,_/ \__,_/  \___//_/

# %% [markdown]
# # Task
# #### Cluster wine dataset using kmean and Agglomerative with a good visualization

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import warnings
warnings.filterwarnings('ignore') 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from scipy.cluster import hierarchy
from scipy.spatial import distance_matrix
from yellowbrick.cluster import KElbowVisualizer

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ## 2. Read Data

# %%
data = pd.read_csv('wine-clustering.csv')
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# 3   3.45     1480
# 4   2.93      735

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
data.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_83cb4_row0_col0, #T_83cb4_row0_col2, #T_83cb4_row1_col0, #T_83cb4_row1_col1, #T_83cb4_row1_col2, #T_83cb4_row1_col3, #T_83cb4_row1_col4, #T_83cb4_row1_col5, #T_83cb4_row1_col6, #T_83cb4_row1_col7, #T_83cb4_row2_col0, #T_83cb4_row2_col1, #T_83cb4_row2_col2, #T_83cb4_row2_col4, #T_83cb4_row2_col5, #T_83cb4_row2_col6, #T_83cb4_row2_col7, #T_83cb4_row3_col0, #T_83cb4_row4_col0, #T_83cb4_row5_col0, #T_83cb4_row5_col1, #T_83cb4_row5_col2, #T_83cb4_row5_col3, #T_83cb4_row5_col4, #T_83cb4_row5_col5, #T_83cb4_row5_col6, #T_83cb4_row5_col7, #T_83cb4_row6_col0, #T_83cb4_row6_col1, #T_83cb4_row6_col2, #T_83cb4_row6_col3, #T_83cb4_row6_col4, #T_83cb4_row6_col5, #T_83cb4_row6_col6, #T_83cb4_row6_col7, #T_83cb4_row7_col0, #T_83cb4_row7_col1, #T_83cb4_row7_col2, #T_83cb4_row7_col3, #T_83cb4_row7_col4, #T_83cb4_row7_col5, #T_83cb4_row7_col6, #T_83cb4_row7_col7, #T_83cb4_row8_col0, #T_83cb4_row8_col1, #T_83cb4_row8_col2, #T_83cb4_row8_col3, #T_83cb4_row8_col4, #T_83cb4_row8_col5, #T_83cb4_row8_col6, #T_83cb4_row8_col7, #T_83cb4_row9_col0, #T_83cb4_row10_col0, #T_83cb4_row10_col1, #T_83cb4_row10_col2, #T_83cb4_row10_col3, #T_83cb4_row10_col4, #T_83cb4_row10_col5, #T_83cb4_row10_col6, #T_83cb4_row10_col7, #T_83cb4_row11_col0, #T_83cb4_row11_col1, #T_83cb4_row11_col2, #T_83cb4_row11_col4, #T_83cb4_row11_col5, #T_83cb4_row11_col6, #T_83cb4_row11_col7, #T_83cb4_row12_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_83cb4_row0_col1, #T_83cb4_row0_col5, #T_83cb4_row0_col6, #T_83cb4_row3_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_83cb4_row0_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_83cb4_row0_col4, #T_83cb4_row3_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_83cb4_row0_col7, #T_83cb4_row3_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_83cb4_row2_col3, #T_83cb4_row9_col1, #T_83cb4_row9_col2, #T_83cb4_row9_col3, #T_83cb4_row9_col4, #T_83cb4_row9_col5, #T_83cb4_row9_col6, #T_83cb4_row9_col7, #T_83cb4_row11_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_83cb4_row3_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_83cb4_row3_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_83cb4_row3_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_83cb4_row3_col6 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_83cb4_row4_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_83cb4_row4_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_83cb4_row4_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_83cb4_row4_col4 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_83cb4_row4_col5 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_83cb4_row4_col6 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_83cb4_row4_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_83cb4_row12_col1, #T_83cb4_row12_col2, #T_83cb4_row12_col3, #T_83cb4_row12_col4, #T_83cb4_row12_col5, #T_83cb4_row12_col6, #T_83cb4_row12_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83cb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83cb4_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_83cb4_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_83cb4_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_83cb4_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_83cb4_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_83cb4_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_83cb4_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_83cb4_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83cb4_level0_row0" class="row_heading level0 row0" >Alcohol</th>
#       <td id="T_83cb4_row0_col0" class="data row0 col0" >178.000000</td>
#       <td id="T_83cb4_row0_col1" class="data row0 col1" >13.000618</td>
#       <td id="T_83cb4_row0_col2" class="data row0 col2" >0.811827</td>
#       <td id="T_83cb4_row0_col3" class="data row0 col3" >11.030000</td>
#       <td id="T_83cb4_row0_col4" class="data row0 col4" >12.362500</td>
#       <td id="T_83cb4_row0_col5" class="data row0 col5" >13.050000</td>
#       <td id="T_83cb4_row0_col6" class="data row0 col6" >13.677500</td>
#       <td id="T_83cb4_row0_col7" class="data row0 col7" >14.830000</td>
#     </tr>
#     <tr>
#       <th id="T_83cb4_level0_row1" class="row_heading level0 row1" >Malic_Acid</th>
#       <td id="T_83cb4_row1_col0" class="data row1 col0" >178.000000</td>
#       <td id="T_83cb4_row1_col1" class="data row1 col1" >2.336348</td>
#       <td id="T_83cb4_row1_col2" class="data row1 col2" >1.117146</td>
#       <td id="T_83cb4_row1_col3" class="data row1 col3" >0.740000</td>
#       <td id="T_83cb4_row1_col4" class="data row1 col4" >1.602500</td>
#       <td id="T_83cb4_row1_col5" class="data row1 col5" >1.865000</td>
#       <td id="T_83cb4_row1_col6" class="data row1 col6" >3.082500</td>
#       <td id="T_83cb4_row1_col7" class="data row1 col7" >5.800000</td>
#     </tr>
#     <tr>
#       <th id="T_83cb4_level0_row2" class="row_heading level0 row2" >Ash</th>
#       <td id="T_83cb4_row2_col0" class="data row2 col0" >178.000000</td>
#       <td id="T_83cb4_row2_col1" class="data row2 col1" >2.366517</td>
#       <td id="T_83cb4_row2_col2" class="data row2 col2" >0.274344</td>
#       <td id="T_83cb4_row2_col3" class="data row2 col3" >1.360000</td>
#       <td id="T_83cb4_row2_col4" class="data row2 col4" >2.210000</td>
#       <td id="T_83cb4_row2_col5" class="data row2 col5" >2.360000</td>
#       <td id="T_83cb4_row2_col6" class="data row2 col6" >2.557500</td>
#       <td id="T_83cb4_row2_col7" class="data row2 col7" >3.230000</td>
#     </tr>
#     <tr>
#       <th id="T_83cb4_level0_row3" class="row_heading level0 row3" >Ash_Alcanity</th>
#       <td id="T_83cb4_row3_col0" class="data row3 col0" >178.000000</td>
#       <td id="T_83cb4_row3_col1" class="data row3 col1" >19.494944</td>
#       <td id="T_83cb4_row3_col2" class="data row3 col2" >3.339564</td>
#       <td id="T_83cb4_row3_col3" class="data row3 col3" >10.600000</td>
#       <td id="T_83cb4_row3_col4" class="data row3 col4" >17.200000</td>
#       <td id="T_83cb4_row3_col5" class="data row3 col5" >19.500000</td>
#       <td id="T_83cb4_row3_col6" class="data row3 col6" >21.500000</td>
#       <td id="T_83cb4_row3_col7" class="data row3 col7" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83cb4_level0_row4" class="row_heading level0 row4" >Magnesium</th>
#       <td id="T_83cb4_row4_col0" class="data row4 col0" >178.000000</td>
#       <td id="T_83cb4_row4_col1" class="data row4 col1" >99.741573</td>
#       <td id="T_83cb4_row4_col2" class="data row4 col2" >14.282484</td>
#       <td id="T_83cb4_row4_col3" class="data row4 col3" >70.000000</td>
#       <td id="T_83cb4_row4_col4" class="data row4 col4" >88.000000</td>
#       <td id="T_83cb4_row4_col5" class="data row4 col5" >98.000000</td>
#       <td id="T_83cb4_row4_col6" class="data row4 col6" >107.000000</td>
#       <td id="T_83cb4_row4_col7" class="data row4 col7" >162.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83cb4_level0_row5" class="row_heading level0 row5" >Total_Phenols</th>
#       <td id="T_83cb4_row5_col0" class="data row5 col0" >178.000000</td>
#       <td id="T_83cb4_row5_col1" class="data row5 col1" >2.295112</td>
#       <td id="T_83cb4_row5_col2" class="data row5 col2" >0.625851</td>
#       <td id="T_83cb4_row5_col3" class="data row5 col3" >0.980000</td>
#       <td id="T_83cb4_row5_col4" class="data row5 col4" >1.742500</td>
#       <td id="T_83cb4_row5_col5" class="data row5 col5" >2.355000</td>
#       <td id="T_83cb4_row5_col6" class="data row5 col6" >2.800000</td>
#       <td id="T_83cb4_row5_col7" class="data row5 col7" >3.880000</td>
#     </tr>
#     <tr>
#       <th id="T_83cb4_level0_row6" class="row_heading level0 row6" >Flavanoids</th>
#       <td id="T_83cb4_row6_col0" class="data row6 col0" >178.000000</td>
#       <td

# %%
plt.subplots(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### 3.1 Detect Outliers

# %% [markdown]
# #### 3.1.1 IQR

# %%
def get_outliers(col, data = data):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    iqr_outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)]
    
    return lower_bound, upper_bound, len(iqr_outliers)

for col in data.columns:
    lower_bound, upper_bound, outliers = get_outliers(col)
    print(f"Number of outliers detected based on IQR method ({str(col).center(20)}) : ", str(outliers).rjust(2), f" | Lower = {str(round(lower_bound, 5)).rjust(7)}", f" -> Upper = {str(round(upper_bound, 2)).rjust(7)}")
# Out:
# Number of outliers detected based on IQR method (      Alcohol       ) :   0  | Lower =   10.39  -> Upper =   15.65
# Number of outliers detected based on IQR method (     Malic_Acid     ) :   3  | Lower = -0.6175  -> Upper =     5.3
# Number of outliers detected based on IQR method (        Ash         ) :   3  | Lower = 1.68875  -> Upper =    3.08
# Number of outliers detected based on IQR method (    Ash_Alcanity    ) :   4  | Lower =   10.75  -> Upper =   27.95
# Number of outliers detected based on IQR method (     Magnesium      ) :   4  | Lower =    59.5  -> Upper =   135.5
# Number of outliers detected based on IQR method (   Total_Phenols    ) :   0  | Lower = 0.15625  -> Upper =    4.39
# Number of outliers detected based on IQR method (     Flavanoids     ) :   0  | Lower =    -1.3  -> Upper =    5.38
# Number of outliers detected based on IQR method (Nonflavanoid_Phenols) :   0  | Lower = 0.01875  -> Upper =    0.69
# Number of outliers detected based on IQR method (  Proanthocyanins   ) :   2  | Lower =     0.2  -> Upper =     3.0
# Number of outliers detected based on IQR method (  Color_Intensity   ) :   4  | Lower =   -1.25  -> Upper =   10.67
# Number of outliers detected based on IQR method (        Hue         ) :   1  | Lower = 0.27625  -> Upper =    1.63
# Number of outliers detected based on IQR method (       OD280        ) :   0  | Lower = 0.08875  -> Upper =    5.02
# Number of outliers detected based on IQR method (      Proline       ) :   0  | Lower = -226.25  -> Upper = 1711.75

# %%
outliers_length =   len(data[(data["Malic_Acid"]      <= -0.6175) | (data["Malic_Acid"]      >= 5.3)|
                             (data["Ash"]             <= 1.68875) | (data["Ash"]             >= 3.08)|
                             (data["Ash_Alcanity"]    <= 10.75)   | (data["Ash_Alcanity"]    >= 27.95)|
                             (data["Magnesium"]       <= 59.5)    | (data["Magnesium"]       >= 135.5)|
                             (data["Proanthocyanins"] <= 0.2)     | (data["Proanthocyanins"] >= 3.0)|
                             (data["Color_Intensity"] <= -1.25)   | (data["Color_Intensity"] >= 10.67)|
                             (data["Hue"]             <= 0.27625) | (data["Hue"]             >= 1.63)])

print(f"Outliers = {round(outliers_length/len(data)*100, 2)}%")
# Out:
# Outliers = 9.55%

# %% [markdown]
# #### 3.1.1 Box Plot

# %%
columns = ["Malic_Acid", "Ash", "Ash_Alcanity", "Magnesium", "Proanthocyanins", "Color_Intensity", "Hue"]

fig, axes = plt.subplots(4, 2, figsize=(16, 16))
axes = axes.flatten()  # Flatten the 4x2 array of axes to iterate easily

for i, column in enumerate(columns):
    sns.boxplot(ax=axes[i], y=data[column])
    axes[i].set_title(f'{column}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel(column)

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2 Data Scaling

# %%
scaler = StandardScaler()
data = scaler.fit_transform(data)

data[:5, :] # Sample
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, -1.16959318,  1.91390522,
#          0.80899739,  1.03481896, -0.65956311,  1.22488398,  0.25171685,
#          0.36217728,  1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, -2.49084714,  0.01814502,
#          0.56864766,  0.73362894, -0.82071924, -0.54472099, -0.29332133,
#          0.40605066,  1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, -0.2687382 ,  0.08835836,
#          0.80899739,  1.21553297, -0.49840699,  2.13596773,  0.26901965,
#          0.31830389,  0.78858745,  1.39514818],
#        [ 1.69154964, -0.34681064,  0.4879264 , -0.80925118,  0.93091845,
#          2.49144552,  1.46652465, -0.98187536,  1.03215473,  1.18606801,
#         -0.42754369,  1.18407144,  2.33457383],
#        [ 0.29570023,  0.22769377,  1.84040254,  0.45194578,  1.28198515,
#          0.80899739,  0.66335127,  0.22679555,  0.40140444, -0.31927553,
#          0.36217728,  0.44960118, -0.03787401]])

# %% [markdown]
# ### 3.3 Dimensionality Reduction using PCA

# %% [markdown]
# #### 3.3.1 Fitting Data to PCA Function

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
data2 = pd.DataFrame(pca.fit_transform(data), columns=['PC1', 'PC2']) 
data2.head()
# Out:
#         PC1       PC2
# 0  3.316751 -1.443463
# 1  2.209465  0.333393
# 2  2.516740 -1.031151
# 3  3.757066 -2.756372
# 4  1.008908 -0.869831

# %% [markdown]
# #### 3.3.2 Visualizing PCA Output

# %%
plt.scatter(data2['PC1'], data2['PC2'])
plt.xlabel("First Principal Component")
plt.ylabel("Second Principal Component")
plt.title(f"Data Scatter After PCA")
plt.show()

# %% [markdown]
# ## 4. Clustering

# %% [markdown]
# ### 4.1 Elbow Visualizer (to detect the optimal number of clusters )

# %%
kMeans_Visualizing = KMeans(random_state=42)
visualizer = KElbowVisualizer(kMeans_Visualizing, k=(2, 10))
 
visualizer.fit(data2)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### 4.2 Modeling

# %% [markdown]
# #### 4.2.1 KMeans Clustering

# %% [markdown]
# ##### 4.2.1.1 Training

# %%
kMeans3_model  = KMeans(n_clusters=3).fit(data2)
data2['Labels'] = kMeans3_model.labels_

# %% [markdown]
# ##### 4.2.1.2 Visualization

# %%
plt.scatter(data2['PC1'], data2['PC2'], c=data2['Labels'], cmap='rainbow')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('K-Means Clustering')
plt.show()

# %% [markdown]
# #### 4.2.2 Hierarchical Clustering

# %% [markdown]
# ##### 4.2.2.1  Dendrogram

# %%
dist = distance_matrix(data2, data2)

# %%
Z = hierarchy.linkage(dist, 'average')
plt.figure(figsize=(50, 50))
dendro = hierarchy.dendrogram(Z, leaf_rotation=0, leaf_font_size =12, orientation = 'top')

# %% [markdown]
# ##### 4.2.2.2 Training

# %%
hc = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')  
y_predict = hc.fit_predict(data2)

# %% [markdown]
# ##### 4.2.2.3 Visualization

# %%
plt.scatter(data2['PC1'], data2['PC2'], c=y_predict, cmap='rainbow')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Agglomerative Clustering')
plt.show()
